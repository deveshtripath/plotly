# %% [markdown]
# <a href="https://colab.research.google.com/github/deveshtripath/plotly/blob/main/Copy_of_task_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perform EDA on below insurance dataset
#
# Link: https://www.kaggle.com/datasets/thedevastator/insurance-claim-analysis-demographic-and-health
#
# Perform All steps of EDA and document conclusions and then perform feature engineering.

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %% [markdown]
# ### Column Types
#
# - **Numerical** - PatientID,age,bmi,bloodpressure,claim
# - **Categorical** - gender,diabetic,children,smoker,region
# - **Mixed** -

# %%
import pandas as pd
df = pd.read_csv('/content/insurance_data.csv')
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.shape
# Out:
# (1340, 11)

# %%
# lets take Univariant analysis
df['age'].isnull().sum()
# Out:
# 5

# %%
df['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].skew()
# Out:
# 0.11361133741072633

# %%
df['age'].describe()
# Out:
# count    1335.000000
# mean       38.078652
# std        11.102924
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
df[df['age'] == 18]
# Out:
#       index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 22       22         23  18.0   male  35.5            100      Yes         0
# 41       41         42  18.0   male  27.8             93       No         0
# 152     152        153  18.0   male  27.6             94      Yes         0
# 244     244        245  18.0   male  25.5             99      Yes         0
# 259     259        260  18.0   male  30.9             92       No         2
# 326     326        327  18.0   male  30.8             97      Yes         0
# 462     462        463  18.0   male  29.8             97       No         2
# 517     517        518  18.0   male  36.0             93       No         2
# 564     564        565  18.0   male  26.6             95       No         1
# 580     580        581  18.0   male  32.0             81      Yes         2
# 632     632        633  18.0   male  32.3             98      Yes         1
# ...

# %%
import seaborn as sns
sns.displot(kind='hist',data=df['age'],kde=True)

# %%
sns.boxplot(data=df['age'])
# Out:
# <Axes: >

# %%
# bmi
df['bmi']
# Out:
# 0       23.2
# 1       30.1
# 2       33.3
# 3       33.7
# 4       34.1
#         ...
# 1335    35.5
# 1336    38.1
# 1337    34.5
# 1338    30.4
# 1339    47.4
# Name: bmi, Length: 1340, dtype: float64

# %%
df['bmi'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bmi'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(kind='hist',data=df['bmi'],kde=True)

# %%
df['bmi'].skew()
# Out:
# 0.28597245020808587

# %%
df['bmi'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['bmi'] > 47]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 9         9         10  30.0    male  53.1             97       No         0
# 141     141        142  46.0    male  50.4             89      Yes         1
# 579     579        580  25.0    male  47.5             84      Yes         1
# 675     675        676  49.0  female  48.1             81      Yes         2
# 696     696        697  49.0    male  47.7             88       No         1
# 802     802        803  42.0    male  49.1            109      Yes         0
# 1299   1299       1300  50.0    male  52.6            110       No         1
# 1306   1306       1307  43.0  female  47.6            112      Yes         2
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# 9        No  northwest   1163.46
# 141      No  southeast   2438.06
# 579      No  southeast   8083.92
# 675      No  northeast   9432.93
# ...

# %%
df['bmi'].isnull().sum()
# Out:
# 0

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
# bloodpressure
df['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
df['bloodpressure'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bloodpressure'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['bloodpressure'].skew()
# Out:
# 1.4835342102293079

# %%
df['bloodpressure'].isnull().sum()
# Out:
# 0

# %%
df['bloodpressure'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['bloodpressure'] > 120]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1147   1147       1148  29.0  female  32.7            128      Yes         2
# 1150   1150       1151  55.0  female  27.1            135       No         1
# 1152   1152       1153  38.0  female  35.9            128       No         1
# 1153   1153       1154  43.0    male  36.8            126       No         2
# 1154   1154       1155  31.0    male  23.8            126      Yes         0
# 1156   1156       1157  46.0  female  23.0            137      Yes         0
# 1161   1161       1162  22.0    male  22.4            137      Yes         2
# 1166   1166       1167  23.0    male  26.7            123      Yes         0
# 1169   1169       1170  27.0    male  36.7            130       No         1
# 1174   1174       1175  44.0  female  29.1            139       No         0
# 1181   1181       1182  32.0    male  28.6            132       No         0
# ...

# %%
# claim
df['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
df['claim'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(kind='hist',data=df['claim'],kde=True)

# %%
df['claim'].skew()
# Out:
# 1.5167468509489237

# %%
df['claim'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['claim'].isnull().sum()
# Out:
# 0

# %%
# categorical analysis
# gender,diabetic,children,smoker,region

# %%
df['gender'].value_counts()
# Out:
# male      678
# female    662
# Name: gender, dtype: int64

# %%
df['gender'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='gender'>

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %%
# diabetic
df['diabetic'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='diabetic'>

# %%
# children
df['children'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='children'>

# %%
# df.info()

# %%
# smoker
df['smoker'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='smoker'>

# %%
# region
df['region'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='region'>

# %%
# bivarient analysis

# %%
df.columns
# Out:
# Index(['index', 'PatientID', 'age', 'gender', 'bmi', 'bloodpressure',
#        'diabetic', 'children', 'smoker', 'region', 'claim'],
#       dtype='object')

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
# there are three type of bivarient analysis
# 1. numerical -numerical
# 2. categorical - numerical
# 3. categorical -categorical

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='gender',y='bmi')
plt.xticks(rotation='vertical')

plt.show()

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='gender',y='claim')
plt.xticks(rotation='vertical')

plt.show()

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='diabetic',y='bmi')
plt.xticks(rotation='vertical')

plt.show()

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='diabetic',y='bmi')
plt.xticks(rotation='vertical')

plt.show()

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='smoker',y='claim')
plt.xticks(rotation='vertical')

plt.show()

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='smoker',y='bloodpressure')
plt.xticks(rotation='vertical')

plt.show()

# %%
# categorical - numerical
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.catplot(data=df,x='region',y='claim',kind='bar')
plt.xticks(rotation='vertical')

plt.show()

# %%
# Numerical - PatientID,age,bmi,bloodpressure,claim
# Categorical - gender,diabetic,children,smoker,region

# categorical - categorical

# crosstab

pd.crosstab(df['gender'],df['diabetic'])
# Out:
# diabetic   No  Yes
# gender
# female    339  323
# male      359  319

# %%
sns.heatmap(pd.crosstab(df['gender'],df['diabetic']))
# Out:
# <Axes: xlabel='diabetic', ylabel='gender'>

# %%
# Categorical - gender,diabetic,children,smoker,region
pd.crosstab(df['gender'],df['smoker'])
# Out:
# smoker   No  Yes
# gender
# female  547  115
# male    519  159

# %%
sns.heatmap(pd.crosstab(df['gender'],df['smoker']))
# Out:
# <Axes: xlabel='smoker', ylabel='gender'>

# %%
pd.crosstab(df['gender'],df['region'])
# Out:
# region  northeast  northwest  southeast  southwest
# gender
# female        112        164        224        162
# male          119        185        219        152

# %%
pd.crosstab(df['diabetic'],df['smoker'])
# Out:
# smoker     No  Yes
# diabetic
# No        560  138
# Yes       506  136

# %%
sns.heatmap(pd.crosstab(df['diabetic'],df['smoker']))
# Out:
# <Axes: xlabel='smoker', ylabel='diabetic'>

# %%
sns.pairplot(df)
